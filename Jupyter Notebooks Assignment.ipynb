# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Amanda Puentes**
# Psychological Research Data Analyst

# %% [markdown]
# *I am interested in data science because I want to be apart of the research team without being directly involved with research subjects.*

# %% [markdown]
# ### The code below will show the sum of the two numbers

# %%
3 + 3
# Out:
# 6

# %% [markdown]
#  - This
#  - Is a bulleted list
#  - For this assignment
#
# >This is a Block Quote just below the Bulleted List. This Block Quote also has a Horizontal Rule below it
# ---
